# %%
! pip install langchain langchain-community langchain-chroma "unstructured[all-docs]" pydantic lxml
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.19)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.18)
# Requirement already satisfied: langchain-chroma in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (2.11.0a2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: unstructured[all-docs] in /usr/local/lib/python3.10/dist-packages (0.16.23)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.35 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.40)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.12)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: numpy<2,>=1.26.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-chroma) (0.6.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.4.27)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.3)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.14.1)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2025.2.18)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.12.1)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.2)
# Requirement already satisfied: unstructured-client in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.30.6)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.9.5)
# Requirement already satisfied: python-oxmsg in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.0.2)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.2.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (20240706)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.7)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.1.5)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.4.2)
# Requirement already satisfied: google-cloud-vision in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.10.0)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.3.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.3.13)
# Requirement already satisfied: unstructured-inference>=0.8.7 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.8.7)
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (9.5.2)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.15)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: python-docx>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.1.2)
# Requirement already satisfied: pi-heif in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.21.0)
# Requirement already satisfied: python-pptx>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (2.29.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.17.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.13.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (24.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.26.4->langchain) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.26.4->langchain) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.26.4->langchain) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.26.4->langchain) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.26.4->langchain) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.26.4->langchain) (2.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx>=1.0.1->unstructured[all-docs]) (11.0.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx>=1.0.1->unstructured[all-docs]) (3.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (0.0.20)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (0.29.0)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (3.7.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (2.5.1+cu121)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (1.0.12)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (4.47.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (1.13.1)
# Requirement already satisfied: pypdfium2 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference>=0.8.7->unstructured[all-docs]) (4.30.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[all-docs]) (44.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured[all-docs]) (2.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (0.20.1+cu121)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.34.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (3.20.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured[all-docs]) (0.5.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[all-docs]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2025.1)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from pikepdf->unstructured[all-docs]) (1.2.15)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from python-oxmsg->unstructured[all-docs]) (8.1.7)
# Requirement already satisfied: olefile in /usr/local/lib/python3.10/dist-packages (from python-oxmsg->unstructured[all-docs]) (0.47)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (24.1.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (1.6.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.17.1)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.45.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.66.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain) (3.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.13.1)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (8.4.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (75.1.0)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference>=0.8.7->unstructured[all-docs]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference>=0.8.7->unstructured[all-docs]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference>=0.8.7->unstructured[all-docs]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference>=0.8.7->unstructured[all-docs]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference>=0.8.7->unstructured[all-docs]) (3.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.19.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->unstructured-inference>=0.8.7->unstructured[all-docs]) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference>=0.8.7->unstructured[all-docs]) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference>=0.8.7->unstructured[all-docs]) (2024.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->unstructured-inference>=0.8.7->unstructured[all-docs]) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference>=0.8.7->unstructured[all-docs]) (2024.11.6)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (14.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2,>=1.26.4->langchain) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2,>=1.26.4->langchain) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<2,>=1.26.4->langchain) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<2,>=1.26.4->langchain) (2024.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.21.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<2,>=1.26.4->langchain) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->unstructured-inference>=0.8.7->unstructured[all-docs]) (3.0.2)

# %%
# !apt-get update
# !apt-get install -y poppler-utils
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 137 not upgraded.

# %%
from typing import Any

from pydantic import BaseModel
from unstructured.partition.pdf import partition_pdf

data_folder = "/kaggle/input/diabetes-book/Handbook of Diabetes.pdf"
# Path to save images
extracted_img = "/kaggle/working/"

# Get elements
raw_pdf_elements = partition_pdf(
    filename=data_folder,
    # Using pdf format to find embedded image blocks
    extract_images_in_pdf=True,
    # Use layout model (YOLOX) to get bounding boxes (for tables) and find titles
    # Titles are any sub-section of the document
    infer_table_structure=True,
    # Post processing to aggregate text once we have the title
    chunking_strategy="by_title",
    # Chunking params to aggregate text blocks
    # Attempt to create a new chunk 3800 chars
    # Attempt to keep chunks > 2000 chars
    # Hard max on chunks
    max_characters=4000,
    new_after_n_chars=3800,
    combine_text_under_n_chars=2000,
    image_output_dir_path=extracted_img,
)
# Out:
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]

# %%
# Create a dictionary to store counts of each type
category_counts = {}

for element in raw_pdf_elements:
    category = str(type(element))
    if category in category_counts:
        category_counts[category] += 1
    else:
        category_counts[category] = 1

# Unique_categories will have unique elements
# TableChunk if Table > max chars set above
unique_categories = set(category_counts.keys())
category_counts
# Out:
# {"<class 'unstructured.documents.elements.CompositeElement'>": 388}

# %%
class Element(BaseModel):
    type: str
    text: Any


# Categorize by type
categorized_elements = []
for element in raw_pdf_elements:
    if "unstructured.documents.elements.Table" in str(type(element)):
        categorized_elements.append(Element(type="table", text=str(element)))
    elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
        categorized_elements.append(Element(type="text", text=str(element)))

# Tables
table_elements = [e for e in categorized_elements if e.type == "table"]
print(len(table_elements))

# Text
text_elements = [e for e in categorized_elements if e.type == "text"]
print(len(text_elements))
# Out:
# 0
# 388

# %%
# !pip install -U langchain_ollama
# Out:
# Collecting langchain_ollama
#   Downloading langchain_ollama-0.2.3-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in /usr/local/lib/python3.10/dist-packages (from langchain_ollama) (0.3.40)
# Collecting ollama<1,>=0.4.4 (from langchain_ollama)
#   Downloading ollama-0.4.7-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (0.2.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_ollama) (2.11.0a2)
# Requirement already satisfied: httpx<0.29,>=0.27 in /usr/local/lib/python3.10/dist-packages (from ollama<1,>=0.4.4->langchain_ollama) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (3.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_ollama) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain_ollama) (1.2.2)
# Downloading langchain_ollama-0.2.3-py3-none-any.whl (19 kB)
# Downloading ollama-0.4.7-py3-none-any.whl (13 kB)
# Installing collected packages: ollama, langchain_ollama
# Successfully installed langchain_ollama-0.2.3 ollama-0.4.7

# %%
#Download ollama
# !curl -fsSL https://ollama.com/install.sh | sh
import subprocess
process = subprocess.Popen("ollama serve", shell=True) #runs on a different thread
#Download model
# !ollama pull llama2
# !pip install ollama
import ollama

# %%
from langchain_community.llms import Ollama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
# Prompt
prompt_text = """You are an assistant tasked with summarizing tables and text. \
Give a concise summary of the table or text. Table or text chunk: {element} """
prompt = ChatPromptTemplate.from_template(prompt_text)

# Summary chain
model = Ollama(model="llama2")
summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()
# Out:
# <ipython-input-10-00f148a5e9fd>:7: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   model = Ollama(model="llama2")

# %%
# Apply to text
texts = [i.text for i in text_elements if i.text != ""]
text_summaries = summarize_chain.batch(texts, {"max_concurrency": 5})

# %%
# Apply to tables
tables = [i.text for i in table_elements]
table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})

# %%
# !ollama pull llava
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 170370233dd5...   0% ▕                ▏    0 B/4.1 GB                  pulling manifest
# pulling 170370233dd5...   0% ▕                ▏    0 B/4.1 GB                  pulling manifest
# pulling 170370233dd5...   0% ▕                ▏  17 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...   1% ▕                ▏  48 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...   2% ▕                ▏  81 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...   4% ▕                ▏ 145 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...   4% ▕                ▏ 180 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...   6% ▕█               ▏ 257 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...   8% ▕█               ▏ 323 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...  10% ▕█               ▏ 392 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...  10% ▕█               ▏ 425 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5...  12% ▕█               ▏ 493 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  13% ▕██              ▏ 528 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  15% ▕██              ▏ 598 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  16% ▕██              ▏ 663 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  18% ▕██              ▏ 735 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  19% ▕███             ▏ 772 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  20% ▕███             ▏ 835 MB/4.1 GB  458 MB/s      7spulling manifest
# pulling 170370233dd5...  22% ▕███             ▏ 902 MB/4.1 GB  458 MB/s      6spulling manifest
# pulling 170370233dd5...  23% ▕███             ▏ 937 MB/4.1 GB  458 MB/s      6spulling manifest
# pulling 170370233dd5...  24% ▕███             ▏ 1.0 GB/4.1 GB  458 MB/s      6spulling manifest
# pulling 170370233dd5...  26% ▕████            ▏ 1.1 GB/4.1 GB
# pulling 170370233dd5...  90% ▕██████████████  ▏ 3.7 GB/4.1 GB  153 MB/s      2spulling manifest
# pulling 170370233dd5...  92% ▕██████████████  ▏ 3.8 GB/4.1 GB  208 MB/s      1spulling manifest
# pulling 170370233dd5...  93% ▕██████████████  ▏ 3.8 GB/4.1 GB  208 MB/s      1spulling manifest
# pulling 170370233dd5...  94% ▕███████████████ ▏ 3.9 GB/4.1 GB  208 MB/s      1spulling manifest
# pulling 170370233dd5...  96% ▕███████████████ ▏ 3.9 GB/4.1 GB  208 MB/s      0spulling manifest
# pulling 170370233dd5...  97% ▕███████████████ ▏ 4.0 GB/4.1 GB  208 MB/s      0spulling manifest
# pulling 170370233dd5...  98% ▕███████████████ ▏ 4.0 GB/4.1 GB  208 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕███████████████ ▏ 4.1 GB/4.1 GB  208 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕███████████████ ▏ 4.1 GB/4.1 GB  208 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕███████████████ ▏ 4.1 GB/4.1 GB  208 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...   0% ▕                ▏    0 B/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...   1% ▕                ▏ 9.2 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...   6% ▕                ▏  36 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  10% ▕█               ▏  63 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  21% ▕███             ▏ 129 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  30% ▕████            ▏ 187 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  40% ▕██████          ▏ 248 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  45% ▕███████         ▏ 278 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  54% ▕████████        ▏ 334 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  63% ▕██████████      ▏ 395 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  68% ▕██████████      ▏ 425 MB/624 MB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  78% ▕████████████    ▏ 485 MB/624 MB  456 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  88% ▕██████████████  ▏ 548 MB/624 MB  456 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  93% ▕██████████████  ▏ 582 MB/624 MB  456 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6...  99% ▕███████████████ ▏ 619 MB/624 MB  456 MB/s      0spulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53...   0% ▕                ▏    0 B/ 11 KB                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573...   0% ▕                ▏    0 B/  67 B                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d...   0% ▕                ▏    0 B/  30 B                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5...   0% ▕                ▏    0 B/ 564 B                  pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B                         pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# ...
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 170370233dd5... 100% ▕████████████████▏ 4.1 GB
# pulling 72d6f08a42f6... 100% ▕████████████████▏ 624 MB
# pulling 43070e2d4e53... 100% ▕████████████████▏  11 KB
# pulling c43332387573... 100% ▕████████████████▏   67 B
# pulling ed11eda7790d... 100% ▕████████████████▏   30 B
# pulling 7c658f9561e5... 100% ▕████████████████▏  564 B
# verifying sha256 digest
# writing manifest
# success

# %%
import os
import base64
import json
import requests
from pathlib import Path

# Define the directory containing the images
IMG_DIR = "/kaggle/working/figures/"

# Create a function to process an image with LLaVA
def process_image_with_llava(image_path):
    # Check if the image exists
    if not os.path.exists(image_path):
        return f"Image not found: {image_path}"
    
    try:
        # Read and encode the image to base64
        with open(image_path, "rb") as img_file:
            base64_image = base64.b64encode(img_file.read()).decode('utf-8')
        
        # Prepare the request payload
        payload = {
            "model": "llava",
            "prompt": "Describe the image in detail. If it contains graphs, charts, or medical illustrations, explain what they show regarding diabetes.",
            "images": [base64_image],
            "stream": False
        }
        
        # Make the API call to Ollama
        response = requests.post("http://localhost:11434/api/generate", json=payload)
        
        # Process the response
        if response.status_code == 200:
            result = response.json()
            return result.get("response", "No description generated")
        else:
            return f"Error: {response.status_code}, {response.text}"
    
    except Exception as e:
        return f"Error processing image: {str(e)}"

# Process all images in the directory
def process_all_images():
    # Create the directory if it doesn't exist
    Path(IMG_DIR).mkdir(parents=True, exist_ok=True)
    
    # Get all image files
    image_files = [f for f in os.listdir(IMG_DIR) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    results = {}
    
    for img_file in image_files:
        img_path = os.path.join(IMG_DIR, img_file)
        output_file = os.path.join(IMG_DIR, os.path.splitext(img_file)[0] + ".txt")
        
        # Process the image
        description = process_image_with_llava(img_path)
        
        # Save the description to a text file
        with open(output_file, "w") as f:
            f.write(description)
        
        # Store in results dictionary
        results[img_file] = description
        print(f"Processed {img_file}")
    
    return results

# Execute the function
image_descriptions = process_all_images()

# Print a summary
print(f"Processed {len(image_descriptions)} images")
for img, desc in image_descriptions.items():
    print(f"\n--- {img} ---")
    # Print first 100 characters of description
    print(desc[:100] + "..." if len(desc) > 100 else desc)
# Out:
# Processed figure-93-99.jpg
# Processed figure-128-356.jpg
# Processed figure-108-184.jpg
# Processed figure-108-126.jpg
# Processed figure-272-541.jpg
# Processed figure-180-434.jpg
# Processed figure-288-550.jpg
# Processed figure-73-83.jpg
# Processed figure-108-322.jpg
# Processed figure-108-315.jpg
# Processed figure-64-72.jpg
# Processed figure-108-314.jpg
# Processed figure-203-468.jpg
# Processed figure-198-459.jpg
# Processed figure-24-15.jpg
# Processed figure-137-370.jpg
# Processed figure-108-222.jpg
# Processed figure-110-341.jpg
# Processed figure-77-86.jpg
# Processed figure-108-289.jpg
# Processed figure-108-252.jpg
# Processed figure-108-156.jpg
# Processed figure-62-65.jpg
# Processed figure-117-345.jpg
# Processed figure-108-312.jpg
# Processed figure-194-447.jpg
# Processed figure-294-555.jpg
# Processed figure-108-220.jpg
# Processed figure-108-129.jpg
# Processed figure-108-185.jpg
# Processed figure-108-225.jpg
# Processed figure-62-66.jpg
# Processed figure-144-383.jpg
# Processed figure-162-410.jpg
# Processed figure-108-187.jpg
# Processed figure-72-82.jpg
# Processed figure-108-291.jpg
# Processed figure-108-246.jpg
# Processed figure-108-148.jpg
# Processed figure-94-100.jpg
# Processed figure-108-212.jpg
# Processed figure-108-331.jpg
# Processed figure-108-215.jpg
# Processed figure-136-368.jpg
# Processed figure-167-414.jpg
# Processed figure-108-165.jpg
# Processed figure-297-558.jpg
# Processed figure-108-127.jpg
# Processed figure-108-138.jpg
# Processed figure-108-200.jpg
# Processed figure-172-425.jpg
# Processed figure-43-44.jpg
# Processed figure-59-63.jpg
# Processed figure-201-464.jpg
# Processed figure-237-526.jpg
# Processed figure-108-208.jpg
# Processed figure-108-243.jpg
# Processed figure-108-216.jpg
# Processed figure-224-509.jpg
# Processed figure-108-245.jpg
# Processed figure-127-354.jpg
# Processed figure-277-545.jpg
# Processed figure-50-54.jpg
# Processed figure-108-131.jpg
# Processed figure-108-136.jpg
# Processed figure-224-495.jpg
# Processed figure-108-116.jpg
# Processed figure-160-403.jpg
# Processed figure-108-328.jpg
# Processed figure-126-353.jpg
# Processed figure-235-518.jpg
# Processed figure-108-333.jpg
# Processed figure-25-16.jpg
# Processed figure-202-465.jpg
# Processed figure-193-446.jpg
# Processed figure-108-218.jpg
# Processed figure-108-223.jpg
# Processed figure-134-365.jpg
# Processed figure-35-27.jpg
# Processed figure-113-343.jpg
# Processed figure-108-206.jpg
# Processed figure-224-489.jpg
# Processed figure-72-81.jpg
# Processed figure-36-28.jpg
# Processed figure-60-64.jpg
# Processed figure-108-256.jpg
# Processed figure-108-293.jpg
# Processed figure-108-255.jpg
# Processed figure-108-211.jpg
# Processed figure-1-2.jpg
# Processed figure-145-387.jpg
# Processed figure-108-231.jpg
# Processed figure-74-85.jpg
# Processed figure-81-87.jpg
# Processed figure-103-111.jpg
# Processed figure-108-173.jpg
# Processed figure-158-402.jpg
# Processed figure-108-332.jpg
# Processed figure-1-1.jpg
# Processed figure-174-427.jpg
# Processed figure-108-334.jpg
# Processed figure-20-10.jpg
# Processed figure-108-135.jpg
# Processed figure-192-441.jpg
# Processed figure-108-263.jpg
# Processed figure-251-531.jpg
# Processed figure-90-95.jpg
# Processed figure-221-487.jpg
# Processed figure-146-390.jpg
# Processed figure-197-456.jpg
# Processed figure-40-40.jpg
# Processed figure-161-408.jpg
# Processed figure-108-179.jpg
# Processed figure-108-319.jpg
# Processed figure-160-404.jpg
# Processed figure-235-519.jpg
# Processed figure-108-214.jpg
# Processed figure-204-470.jpg
# Processed figure-234-515.jpg
# Processed figure-1-3.jpg
# Processed figure-217-483.jpg
# Processed figure-108-283.jpg
# Processed figure-36-30.jpg
# Processed figure-23-13.jpg
# Processed figure-108-155.jpg
# Processed figure-108-227.jpg
# Processed figure-131-358.jpg
# Processed figure-108-247.jpg
# Processed figure-146-391.jpg
# Processed figure-96-103.jpg
# Processed figure-127-355.jpg
# Processed figure-108-313.jpg
# Processed figure-199-462.jpg
# Processed figure-187-439.jpg
# Processed figure-125-352.jpg
# Processed figure-176-432.jpg
# Processed figure-108-119.jpg
# Processed figure-205-472.jpg
# Processed figure-192-444.jpg
# Processed figure-132-362.jpg
# Processed figure-178-433.jpg
# Processed 558 images
#
# --- figure-93-99.jpg ---
#  The image is a scientific illustration that depicts a process related to diabetes. On the left side...
#
# --- figure-128-356.jpg ---
#  The image displays a flowchart that outlines the interactions between a patient with glucose imbala...
#
# --- figure-108-184.jpg ---
#  The image you've provided appears to be a photograph of an outdoor scene with a focus on a portion ...
#
# --- figure-108-126.jpg ---
#  The image appears to be a screenshot from a video platform, as indicated by the interface elements ...
#
# --- figure-272-541.jpg ---
#  The image is a flowchart that outlines a process related to health care services and patient outcom...
#
# --- figure-180-434.jpg ---
#  The image shows a cover page with the title "Chapter 19" prominently displayed in large blue font o...
#
# --- figure-288-550.jpg ---
#  The image is a flowchart with various components interconnected by arrows. At the center of the cha...
#
# --- figure-73-83.jpg ---
#  The image is a black and white X-ray of a human torso. It appears to be a lateral chest X-ray, whic...
#
# --- figure-108-322.jpg ---
#  The image provided is a photograph of a poster with a combination of text and graphics. The central...
#
# --- figure-108-315.jpg ---
#  The image is a composite of two separate images. On the left side, there's an abstract graphic with...
#
# --- figure-64-72.jpg ---
#  The image is a diagrammatic representation of biological processes and pathways, specifically relat...
#
# --- figure-108-314.jpg ---
#  The image is a composite of two photographs placed side by side with different colors and orientati...
#
# --- figure-203-468.jpg ---
#  The image is a photograph featuring a close-up view of a human foot with several visible conditions...
#
# --- figure-198-459.jpg ---
#  The image is a scatter plot graph that appears to be related to pharmaceutical drug efficacy and mo...
#
# --- figure-24-15.jpg ---
#  The image is a line graph that shows data related to diabetes over time, which is indicated by a ti...
#
# --- figure-137-370.jpg ---
#  The image is a flowchart diagram representing a biological pathway related to diabetes and metaboli...
#
# --- figure-108-222.jpg ---
#  The image provided is a photograph showing an out-of-focus view of a landscape with what appears to...
#
# --- figure-110-341.jpg ---
#  The image is a composite of three panels, each depicting anatomical structures in a medical context...
#
# --- figure-77-86.jpg ---
#  The image features a graphic design with text and numbers against a light background. At the top le...
#
# --- figure-108-289.jpg ---
#  The image shows a stylized, colorful drawing of a cartoon character with a purple head and body. Th...
#
# --- figure-108-252.jpg ---
#  The image appears to be a photograph taken at an angle with a blurry focus on the subject, which se...
#
# --- figure-108-156.jpg ---
#  The image you've provided appears to be a screenshot from a smartphone displaying a photo of a colo...
#
# --- figure-62-65.jpg ---
#  The image displays a bar chart with data points that represent percentages related to diabetes. The...
#
# --- figure-117-345.jpg ---
#  The image is a photograph of a printed document, specifically a medical form titled "ADULT DIABET K...
#
# --- figure-108-312.jpg ---
#  The image depicts a diagram of a pipe system, specifically focusing on an elbow joint where two pip...
#
# --- figure-194-447.jpg ---
#  The image is a colorful flowchart that outlines a scientific or biological process related to diabe...
#
# --- figure-294-555.jpg ---
#  The image is a cover of a book titled "CHAPTER 34". At the bottom of the page, there's a number "34...
#
# --- figure-108-220.jpg ---
#  The image you've provided appears to be a low-resolution photograph of a physical object, which loo...
#
# --- figure-108-129.jpg ---
#  The image appears to be a screenshot from a video or presentation, as indicated by the controls for...
#
# --- figure-108-185.jpg ---
#  The image provided appears to be a close-up photograph of a surface with some textures and possibly...
#
# --- figure-108-225.jpg ---
#  The image you've provided is a pixelated image of a computer monitor displaying a blurry photo of a...
#
# --- figure-62-66.jpg ---
#  The image is a graphical representation of data, specifically a scatter plot with a x-axis labeled ...
#
# --- figure-144-383.jpg ---
#  The image shows a high-resolution close-up of an eye with visible retinal layers and blood vessels,...
#
# --- figure-162-410.jpg ---
#  The image displays a line graph with two sets of data representing the mean ± standard error, one i...
#
# --- figure-108-187.jpg ---
#  The image appears to be a screenshot from a computer or mobile device displaying an animated video....
#
# --- figure-72-82.jpg ---
#  The image displays a slice of a human body, likely from a CT scan, focused on the chest area. The o...
#
# --- figure-108-291.jpg ---
#  The image provided appears to be a low-resolution composite of two different photos, with one photo...
#
# --- figure-108-246.jpg ---
#  The image provided is of a low resolution and appears to be a small section of a larger photo. It s...
#
# --- figure-108-148.jpg ---
#  The image appears to be a composite with two different parts:
#
# 1. On the left side of the image is ...
#
# --- figure-94-100.jpg ---
#  The image is a detailed anatomical illustration of a human body with overlaid labels indicating var...
#
# --- figure-108-212.jpg ---
#  The image is a close-up of two different substances, with their textures and colors distinctly visi...
#
# --- figure-108-331.jpg ---
#  The image shows a close-up view of what appears to be a portion of a book with its pages flattened....
#
# --- figure-108-215.jpg ---
#  The image you've provided appears to be a close-up of some text with a blurred background, making i...
#
# --- figure-136-368.jpg ---
#  The image is a digital slide, possibly from a presentation, with a white background and text in bla...
#
# --- figure-167-414.jpg ---
#  The image displays a cover page with text and a simple graphic element. On the right side of the pa...
#
# --- figure-108-165.jpg ---
#  The image shows a very close-up view of what appears to be a person's face, specifically focusing o...
#
# --- figure-297-558.jpg ---
#  The image is a detailed scientific diagram that represents the interactions within a cell during in...
#
# --- figure-108-127.jpg ---
#  The image you've shared is a very low-resolution image that appears to be from a video game, likely...
#
# --- figure-108-138.jpg ---
#  The image displays a graphic that resembles a cross-section of an organ or part of an animal, possi...
#
# --- figure-108-200.jpg ---
#  The image you provided is a photograph that appears to be out of focus and taken at an angle, makin...
#
# --- figure-172-425.jpg ---
#  The image depicts an educational infographic designed to explain various terms related to diabetes....
#
# --- figure-43-44.jpg ---
#  The image is a digital diagram with annotations that provide information about the structure and fu...
#
# --- figure-59-63.jpg ---
#  The image is a graphical representation showing different percentages of various countries with the...
#
# --- figure-201-464.jpg ---
#  The image displays a graphic representation of a book cover with the title "CHAPTER 21" prominently...
#
# --- figure-237-526.jpg ---
#  The image shows a close-up view of a person's hand with multiple irregular nails. Some nails are di...
#
# --- figure-108-208.jpg ---
#  The image provided appears to be a screenshot from a video platform, as indicated by the play butto...
#
# --- figure-108-243.jpg ---
#  The image you've shared is blurry and of low resolution, making it difficult to discern specific de...
#
# --- figure-108-216.jpg ---
#  The image you've provided is very blurry and lacks clear details that could be described in detail....
#
# --- figure-224-509.jpg ---
#  The image you've shared is quite blurry and lacks clarity to describe its content accurately. It ap...
#
# --- figure-108-245.jpg ---
#  The image you've provided is a low-resolution photograph showing a part of a room with a focus on a...
#
# --- figure-127-354.jpg ---
#  The image is a flowchart diagram with text and arrows to depict a cycle of events related to hypert...
#
# --- figure-277-545.jpg ---
#  The image is a digital representation of a page from a book or e-book, as indicated by the layout a...
#
# --- figure-50-54.jpg ---
#  The image appears to be a microscopic image of tissue stained with Hematoxylin and Eosin (H&E), whi...
#
# --- figure-108-131.jpg ---
#  The image you've provided is of low quality and resolution, making it difficult to discern specific...
#
# --- figure-108-136.jpg ---
#  The image appears to be a medical diagram with a focus on a section of an organ that has been label...
#
# --- figure-224-495.jpg ---
#  The image appears to be a close-up photograph of a dark surface with indistinct textures and an obj...
#
# --- figure-108-116.jpg ---
#  The image appears to be a screenshot of a presentation slide related to scientific or educational c...
#
# --- figure-160-403.jpg ---
#  The image is a slide from a presentation, which seems to be discussing a study or experiment relate...
#
# --- figure-108-328.jpg ---
#  The image you've provided is a screenshot from a video or animation. It shows a stylized character ...
#
# --- figure-126-353.jpg ---
#  The image is a composite of three separate graphical representations, each accompanied by text. The...
#
# --- figure-235-518.jpg ---
#  The image shows a person with dark hair from behind. They are wearing a red top and have a light br...
#
# --- figure-108-333.jpg ---
#  The image is a split-screen with two distinct parts. On the left side, there is a photograph of a p...
#
# --- figure-25-16.jpg ---
#  The image is a grayscale graphical representation of data that is likely related to a clinical tria...
#
# --- figure-202-465.jpg ---
#  The image is a graphical representation of a diagram that outlines a pathway leading from an input ...
#
# --- figure-193-446.jpg ---
#  The image is a grayscale line graph with a title and labels on the axes, but it appears to be rotat...
#
# --- figure-108-218.jpg ---
#  The image is a close-up photograph of a textured surface that appears to be a part of an interior w...
#
# --- figure-108-223.jpg ---
#  The image provided is a very low-resolution and blurry photograph that does not contain any clear d...
#
# --- figure-134-365.jpg ---
#  The image is a bar graph with three bars representing different variables related to vascular event...
#
# --- figure-35-27.jpg ---
#  The image you've provided appears to be a microscopic slide stained with hematoxylin and eosin (H&E...
#
# --- figure-113-343.jpg ---
#  The image is a graphical representation combining two separate charts to compare data related to di...
#
# --- figure-108-206.jpg ---
#  The image you've provided appears to be blurry and of low resolution, making it difficult to discer...
#
# --- figure-224-489.jpg ---
#  The image is an educational diagram that explains a concept related to metabolism and inflammation,...
#
# --- figure-72-81.jpg ---
#  The image shows a close-up of an eye with a funduscopy view, typically used in ophthalology to exam...
#
# --- figure-36-28.jpg ---
#  The image is a digital representation of a microscopic view, likely taken from a slide with immunoh...
#
# --- figure-60-64.jpg ---
#  The image appears to be a screenshot of an online application or interface that displays a line gra...
#
# --- figure-108-256.jpg ---
#  The image you've provided is quite small and blurry, making it difficult to discern specific detail...
#
# --- figure-108-293.jpg ---
#  The image you provided is very low resolution and it's difficult to make out specific details. It a...
#
# --- figure-108-255.jpg ---
#  The image provided is a grayscale image with low resolution, making it challenging to discern speci...
#
# --- figure-108-211.jpg ---
#  The image appears to be a close-up photograph of what looks like a blurry object with a metallic sh...
#
# --- figure-38-35.jpg ---
#  The image is a three-dimensional rendering of a molecular structure with multiple arms, each contai...
#
# --- figure-218-486.jpg ---
#  The image is a composite of three distinct parts. Each part features a graph with similar design el...
#
# --- figure-108-285.jpg ---
#  The image appears to be a digitally manipulated or low-resolution graphic with an abstract design t...
#
# --- figure-214-479.jpg ---
#  The image shows an object that appears to be a medical device, possibly an insulin pump or a glucos...
#
# --- figure-108-232.jpg ---
#  The image appears to be a close-up of a pixelated object that resembles an eye or lens, with a focu...
#
# --- figure-144-381.jpg ---
#  The image you've shared is a screenshot of a computer monitor displaying a funduscopy image with an...
#
# --- figure-108-207.jpg ---
#  The image you've provided appears to be a close-up of an object with a focus on details that are no...
#
# --- figure-143-377.jpg ---
#  The image you've provided appears to be a screenshot of a computer display showing an ophthalmology...
#
# --- figure-206-474.jpg ---
#  The image features a close-up view of an item that appears to be a leg brace or support device. Thi...
#
# --- figure-108-147.jpg ---
#  The image is a composite of two different views: the top portion appears to be a microscopic view s...
#
# --- figure-54-57.jpg ---
#  The image displays a diagram with various interconnected elements and arrows pointing between them,...
#
# --- figure-17-5.jpg ---
#  The image is a line graph showing trends over time. It compares different health-related metrics ac...
#
# --- figure-235-520.jpg ---
#  The image shows a close-up of a foot with several toes exhibiting necrosis, indicated by darkened s...
#
# --- figure-108-163.jpg ---
#  The image provided is a close-up of fabric with a gradient of pink colors, and it appears to be a s...
#
# --- figure-32-21.jpg ---
#  The image is a vertical bar chart that displays percentages related to some form of data collection...
#
# --- figure-108-306.jpg ---
#  The image shows a close-up of a textured fabric with a gradient from purple to pink. Due to the low...
#
# --- figure-108-266.jpg ---
#  The image is a close-up photograph of an object that appears to be an item of clothing, specificall...
#
# --- figure-41-41.jpg ---
#  The image is a scientific diagram illustrating the mechanism of insulin resistance and its potentia...
#
# --- figure-144-384.jpg ---
#  The image displays a magnified view of an eye with a focus on the retina and choroidal layer. The r...
#
# --- figure-203-467.jpg ---
#  The image is a close-up photograph showing a person's feet with an enlarged view of one foot's bott...
#
# --- figure-106-113.jpg ---
#  The image is a slide from a presentation titled "Diabetes." It appears to be an educational diagram...
#
# --- figure-108-239.jpg ---
#  The image you've provided appears to be a thumbnail for a video or graphic design project. It featu...
#
# --- figure-290-552.jpg ---
#  The image is a slide with a background that appears to be from a presentation, given the layout and...
#
# --- figure-108-189.jpg ---
#  The image is a close-up of an object with a blurred background, making it difficult to discern spec...
#
# --- figure-108-278.jpg ---
#  The image provided appears to be a close-up of a blurry object with text overlaying it. Due to the ...
#
# --- figure-108-172.jpg ---
#  The image you've provided appears to be a low-resolution photograph of a close-up area where there ...
#
# --- figure-50-55.jpg ---
#  The image shows a microscopic view of cells with green fluorescence staining that highlights certai...
#
# --- figure-108-164.jpg ---
#  The image shows a gradient of colors transitioning from purple to pink and then to gray. This could...
#
# --- figure-124-349.jpg ---
#  The image is a flowchart with a medical theme, specifically relating to diabetes management. It's l...
#
# --- figure-260-536.jpg ---
#  The image shows a graphical representation of feto-placental growth and development across differen...
#
# --- figure-138-372.jpg ---
#  The image appears to be a schematic diagram that represents the structure of the thyroid hormone (t...
#
# --- figure-233-514.jpg ---
#  The image is a cover of a book titled "Chapter 26". The chapter number is visible as "26" on the co...
#
# --- figure-205-473.jpg ---
#  The image is a split-screen composition with two halves of an X-ray film presented side by side. On...
#
# --- figure-165-413.jpg ---
#  The image is a graph that shows data related to serum creatinine (SCr) levels over time. It has two...
#
# --- figure-209-476.jpg ---
#  The image displays two columns of text and a diagram illustrating the relationship between symptoms...
#
# --- figure-144-382.jpg ---
#  The image shows a digital representation of an eye with a focus on the retina. At the center of the...
#
# --- figure-108-270.jpg ---
#  The image you've provided appears to be a screenshot of a computer screen with a portion of a graph...
#
# --- figure-108-294.jpg ---
#  The image displays a close-up view of a textured surface with what appears to be the corner of a pr...
#
# --- figure-108-330.jpg ---
#  The image provided is a close-up photograph of a surface with an irregular texture, which appears t...
#
# --- figure-16-4.jpg ---
#  The image is a bar chart with two x-axes and three y-axes, comparing data across different years fo...
#
# --- figure-236-522.jpg ---
#  The image is a split composition with two distinct sections. On the left side of the image, there's...
#
# --- figure-41-42.jpg ---
#  The image is a composite of three different graphs and charts related to biomedical research. The s...
#
# --- figure-234-517.jpg ---
#  The image shows a close-up of a person's leg, with a focus on a red rash with blisters, and a large...
#
# --- figure-108-226.jpg ---
#  The image you've provided appears to be a low-resolution photo of a collection of items, possibly a...
#
# --- figure-171-421.jpg ---
#  The image is a digital composite that seems to be informational or educational, possibly related to...
#
# --- figure-85-92.jpg ---
#  The image you've provided appears to be a scatter plot with annotations overlaid on it. This kind o...
#
# --- figure-108-336.jpg ---
#  The image features a logo with the text "U" in an orange-colored font, which is stylized to resembl...
#
# --- figure-39-36.jpg ---
#  The image appears to be a screenshot of an educational diagram or infographic related to diabetes a...
#
# --- figure-108-154.jpg ---
#  The image you've provided appears to be a screenshot from a computer displaying a cartoon with an o...
#
# --- figure-67-78.jpg ---
#  The image is a stylized, schematic diagram that outlines a system or process related to insulin and...
#
# --- figure-91-96.jpg ---
#  The image is a line graph with three lines representing different variables related to diabetes con...
#
# --- figure-131-359.jpg ---
#  The image is a line graph with a title at the top that reads "Numer of cases." Below the title are ...
#
# --- figure-108-251.jpg ---
#  The image you've shared appears to be a low-resolution photo of a small section of a computer scree...
#
# --- figure-223-488.jpg ---
#  The image is a graphic with textual content. It includes two main pieces of information: a title "C...
#
# --- figure-197-453.jpg ---
#  The image appears to be a slide from a presentation or lecture, as indicated by the number "35" and...
#
# --- figure-155-398.jpg ---
#  The image is a composite of four separate images with accompanying text that explains their role in...
#
# --- figure-108-177.jpg ---
#  The image shows a gray background with several elements overlaid on it:
#
# 1. A blue arrow pointing t...
#
# --- figure-66-74.jpg ---
#  The image you've shared is a photograph of a screen displaying a table with information on biomarke...
#
# --- figure-239-527.jpg ---
#  The image displays a simple cover page for a chapter titled "CHAPTER 27". The text on the cover is ...
#
# --- figure-108-337.jpg ---
#  The image is a screenshot of a digital interface with text that reads "DIABETES - EVERYTHING YOU NE...
#
# --- figure-102-107.jpg ---
#  The image is a digital graphic that includes text and numerical elements. At the top of the image, ...
#
# --- figure-108-121.jpg ---
#  The image you've provided appears to be a low-resolution graphic with text overlaying it. The centr...
#
# --- figure-123-348.jpg ---
#  The image is a diagrammatic representation of a complex system with various components connected by...
#
# --- figure-224-496.jpg ---
#  The image appears to be a screenshot from an application or presentation slide, possibly related to...
#
# --- figure-108-203.jpg ---
#  The image appears to be a close-up of a person's face, with only the lower part visible from just b...
#
# --- figure-224-503.jpg ---
#  The image shows a close-up of a person's face with their eyes closed and lips partially visible. Th...
#
# --- figure-18-7.jpg ---
#  The image you've provided appears to be a page from an old manuscript or book. It is written in a s...
#
# --- figure-217-485.jpg ---
#  The image displays a bar graph and two line graphs, each set against a time axis, comparing three d...
#
# --- figure-108-137.jpg ---
#  The image you've provided appears to be a close-up of a small object with a texture that might be i...
#
# --- figure-163-411.jpg ---
#  The image is a horizontal bar chart with two sets of data represented by different colors and symbo...
#
# --- figure-40-39.jpg ---
#  The image appears to be a scientific diagram or model explaining the process of insulin production ...
#
# --- figure-278-546.jpg ---
#  The image is a scatter plot graph with two overlaid data sets, each represented by different colors...
#
# --- figure-274-544.jpg ---
#  The image shows a person from behind who appears to be standing outdoors as indicated by the natura...
#
# --- figure-175-430.jpg ---
#  The image is a graphical representation displaying data on diabetic patients and their outcomes wit...
#
# --- figure-62-67.jpg ---
#  The image is a bar chart that depicts data related to rural and urban living and how they impact va...
#
# --- figure-108-237.jpg ---
#  The image you've provided appears to be a close-up of an object with a smooth, possibly metallic su...
#
# --- figure-196-449.jpg ---
#  The image is a screenshot of a presentation slide with a graph titled "Hazard Ratio for Engagement ...
#
# --- figure-108-272.jpg ---
#  The image you've provided appears to be a screenshot of a computer screen showing a pixelated graph...
#
# --- figure-146-389.jpg ---
#  The image shows a medical image that appears to be an MRI scan of an eye. In the center of the imag...
#
# --- figure-170-419.jpg ---
#  The image shows a close-up of a person's foot with a focus on the toes and bottom of the foot. Ther...
#
# --- figure-108-167.jpg ---
#  The image provided is quite small and low-resolution, making it challenging to discern specific det...
#
# --- figure-108-159.jpg ---
#  The image is a screenshot of a computer or mobile device displaying a small window with a comic str...
#
# --- figure-194-448.jpg ---
#  The image is a scientific illustration with text that appears to be related to cell biology and pos...
#
# --- figure-86-93.jpg ---
#  The image appears to be a screenshot of a digital display or dashboard with various graphs and nume...
#
# --- figure-197-457.jpg ---
#  The image shows a line graph with two lines representing different groups. On the x-axis is labeled...
#
# --- figure-235-521.jpg ---
#  The image provided is of low resolution and is a bit blurry, which makes it difficult to discern de...
#
# --- figure-30-18.jpg ---
#  The image shows a line graph with the title "DIABETES," but due to the resolution and size of the t...
#
# --- figure-144-385.jpg ---
#  The image is a photograph of an eye with annotations pointing out features. It appears to be a clos...
#
# --- figure-108-321.jpg ---
#  The image provided is a close-up photograph of a wall-mounted object with a brown, elongated shape ...
#
# --- figure-162-409.jpg ---
#  The image is a composite of four line graphs, each depicting different measurements over time. The ...
#
# --- figure-150-395.jpg ---
#  The image is a black and white microscopic photograph of human retina with choroidal neovasculariza...
#
# --- figure-108-191.jpg ---
#  The image you've provided appears to be a low-resolution, out-of-focus photograph that doesn't offe...
#
# --- figure-108-199.jpg ---
#  The image provided appears to be a close-up of a document with text and possibly graphics that are ...
#
# --- figure-146-394.jpg ---
#  The image shows a close-up photograph of a human eye with a significant amount of cloudiness, sugge...
#
# --- figure-108-320.jpg ---
#  The image you've shared appears to be a screenshot from a video or an online presentation with a ve...
#
# --- figure-290-553.jpg ---
#  The image is a circular diagram that appears to be an infographic explaining different aspects rela...
#
# --- figure-20-11.jpg ---
#  The image is a black and white photograph that captures a moment from the past. It features two men...
#
# --- figure-108-202.jpg ---
#  The image you've shared appears to be a screenshot of a computer screen with various elements that ...
#
# --- figure-286-548.jpg ---
#  The image is a diagram that appears to be a conceptual model or explanation of some aspect related ...
#
# --- figure-236-523.jpg ---
#  The image you've provided appears to be a photograph of a human hand and a portion of an arm restin...
#
# --- figure-108-248.jpg ---
#  The image you've provided appears to be a close-up of a person's face at an angle that obscures mos...
#
# --- figure-108-309.jpg ---
#  The image is a zoomed-in section of an image that features a pinkish hue on the right side, which i...
#
# --- figure-63-70.jpg ---
#  The image shows a 3D isometric plot representing relative risk of physical activity on the x-axis a...
#
# --- figure-95-102.jpg ---
#  The image shows a collection of items on a light-colored surface, which appear to be insulin pens, ...
#
# --- figure-108-213.jpg ---
#  The image appears to be a screenshot from a mobile device displaying an application interface with ...
#
# --- figure-31-19.jpg ---
#  The image appears to be a digital graphic, possibly a screenshot from a presentation or a news repo...
#
# --- figure-108-254.jpg ---
#  The image you've provided is too small and of low resolution for me to be able to provide a detaile...
#
# --- figure-36-29.jpg ---
#  The image is a photograph showing a close-up of a surface with water droplets on it and an object t...
#
# --- figure-296-557.jpg ---
#  The image is a detailed, colorful medical illustration that shows an internal view of a person's to...
#
# --- figure-224-508.jpg ---
#  The image you've provided is a simple color transition from left to right. It appears to be a test ...
#
# --- figure-214-480.jpg ---
#  The image shows a clear plastic tube with a white cap on top, which appears to be an insulin pump. ...
#
# --- figure-151-396.jpg ---
#  The image shows a close-up of an eye with dilated pupils, indicating that an ophthalmological exami...
#
# --- figure-108-296.jpg ---
#  The image displays a gradient color palette that transitions from gray at the top to purple towards...
#
# --- figure-108-300.jpg ---
#  The image is a digital graphic that features two animated cartoon characters standing on a platform...
#
# --- figure-172-424.jpg ---
#  The image shows a close-up view of histological tissue sections that appear to be stained with hema...
#
# --- figure-224-492.jpg ---
#  The image you've shared is not clearly visible due to its small size and low resolution. It appears...
#
# --- figure-175-428.jpg ---
#  The image is a graphical representation of a scientific diagram likely related to biology and medic...
#
# --- figure-67-77.jpg ---
#  The image displays three line graphs with annotations, each representing different data related to ...
#
# --- figure-51-56.jpg ---
#  The image provided appears to be a screenshot of a graphical representation, possibly from a scient...
#
# --- figure-124-350.jpg ---
#  The image is a graphical representation of data. It features two distinct plots: one plotting a rel...
#
# --- figure-108-169.jpg ---
#  The image provided is of a low resolution and does not provide sufficient detail to describe with a...
#
# --- figure-50-53.jpg ---
#  The image is a digital screenshot of a scientific figure, specifically a two-panel plot with overla...
#
# --- figure-108-303.jpg ---
#  The image provided appears to be an abstract gradient transitioning from a light gray at the top to...
#
# --- figure-183-437.jpg ---
#  The image is a graphical representation of data related to diabetes risk in various age groups and ...
#
# --- figure-45-49.jpg ---
#  The image shows a graph from a scientific study, which appears to be related to diabetes research, ...
#
# --- figure-108-204.jpg ---
#  The image appears to be a close-up of a person's face with a focus on the eyes, nose, and part of t...
#
# --- figure-175-429.jpg ---
#  The image you've provided appears to be a photograph of an individual with their legs crossed at th...
#
# --- figure-224-500.jpg ---
#  The image provided is of low resolution and appears to be a screenshot of a smartphone displaying a...
#
# --- figure-108-244.jpg ---
#  The image appears to be a close-up photograph of a blurred object against a background that is out ...
#
# --- figure-108-150.jpg ---
#  The image provided is not a clear representation of diabetes-related content. It appears to be an a...
#
# --- figure-192-442.jpg ---
#  The image shows a line graph and a bar chart on a beige background. The line graph represents the p...
#
# --- figure-42-43.jpg ---
#  The image you've provided is a composite of two images placed side by side, and below them, there a...
#
# --- figure-108-145.jpg ---
#  The image is a close-up photograph of a test strip with a red test strip inserted into a glucose me...
#
# --- figure-193-445.jpg ---
#  The image shows an X-ray of a human wrist and hand, with the skeletal structure clearly visible. Th...
#
# --- figure-204-469.jpg ---
#  The image appears to be a slide from a presentation related to healthcare or medical research. The ...
#
# --- figure-251-533.jpg ---
#  The image is a chart that appears to represent statistical data related to diabetes activity among ...
#
# --- figure-108-174.jpg ---
#  The image is a stylized digital art representation of an abstract concept, which appears to be rela...
#
# --- figure-108-198.jpg ---
#  The image appears to be a low-resolution photograph with an overlay of what looks like a graph or c...
#
# --- figure-108-221.jpg ---
#  The image you've provided is a blurred photograph with no clear content to describe. It appears to ...
#
# --- figure-205-471.jpg ---
#  The image shows a pair of human feet placed side by side on a flat surface with a blue backdrop tha...
#
# --- figure-39-38.jpg ---
#  The image displays a microscopic view of cells with dark stained nuclei that appear to be damaged o...
#
# --- figure-168-416.jpg ---
#  The image is a colorful, hand-drawn diagram with annotations and boxes depicting a pathway related ...
#
# --- figure-102-109.jpg ---
#  The image displays a graph titled "HIGH CHOL DETECTS HIGH MUFA DIET". It shows a decreasing trend f...
#
# --- figure-63-68.jpg ---
#  The image is a composite of two different types of data visualizations related to diabetes and obes...
#
# --- figure-108-340.jpg ---
#  The image appears to be a screenshot from an online platform that displays statistical data and gra...
#
# --- figure-134-366.jpg ---
#  The image is a graph from a scientific or academic paper or presentation. It depicts two sets of da...
#
# --- figure-108-190.jpg ---
#  The image you've shared is a bit blurry and rotated, but from what can be discerned, it appears to ...
#
# --- figure-108-329.jpg ---
#  The image shows a screenshot of a smartphone displaying a game or interactive application with a pi...
#
# --- figure-108-235.jpg ---
#  The image you've provided appears to be a photograph that is out of focus. It seems to be showing a...
#
# --- figure-214-482.jpg ---
#  The image is a graphical representation of a study or survey related to medication use and adherenc...
#
# --- figure-32-22.jpg ---
#  The image is a graphical representation with text annotations. At the top, there are three bars sho...
#
# --- figure-253-535.jpg ---
#  The image shows a person lying in bed with visible injury to their head, including a large black an...
#
# --- figure-44-47.jpg ---
#  The image presents a simplified diagram of cellular processes related to glucose absorption and met...
#
# --- figure-38-34.jpg ---
#  The image is a diagram showing a structure that appears to represent a sequence of events or steps,...
#
# --- figure-224-507.jpg ---
# ...
#
# --- figure-167-415.jpg ---
#  The image appears to be a slide from a presentation, with a graphical representation of anatomical ...
#
# --- figure-108-142.jpg ---
#  The image you've shared appears to be a low-resolution photograph of an object that looks like a sm...
#
# --- figure-181-435.jpg ---
#  The image appears to be a flowchart with text and arrows indicating relationships between various f...
#
# --- figure-169-417.jpg ---
#  The image is a composite of several elements:
#
# 1. On the left side of the image, there's a diagram ...
#
# --- figure-122-347.jpg ---
#  The image displays a cover page for a book with a simple and clean design. The title "CHAPTER 13" i...
#
# --- figure-98-105.jpg ---
#  The image displays a line graph with a scatter plot and a label. The graph is set on an axes grid w...
#
# --- figure-253-534.jpg ---
#  The image shows a medical MRI scan of a head, with the top visible portion showing the brain and th...
#
# --- figure-198-461.jpg ---
#  The image shows a bar graph with two y-axes and three x-axes. On the left side of the graph, there ...
#
# --- figure-56-59.jpg ---
#  The image shows a pyramid with five levels of text, each decreasing in size from top to bottom. Sta...
#
# --- figure-108-325.jpg ---
#  The image provided is of low resolution and appears to be a digital screenshot or an image of a com...
#
# --- figure-30-17.jpg ---
#  The image is a colorful infographic featuring a world map at the center with various colored lines ...
#
# --- figure-224-501.jpg ---
#  The image you've provided appears to be a screenshot of a digital interface, likely from a computer...
#
# --- figure-108-217.jpg ---
#  The image appears to be a zoomed-in and rotated photograph of an object with text on its side, whic...
#
# --- figure-132-361.jpg ---
#  The image is a graphical representation with a background that appears to be a bar chart, although ...
#
# --- figure-108-262.jpg ---
#  The image is a composite of two different images merged together. On the left side, there's an abst...
#
# --- figure-108-168.jpg ---
#  The image is a vertical composite of two different images with a pink gradient from top to bottom. ...
#
# --- figure-249-530.jpg ---
#  The image is a graphic with text and numbers. It has the title "CHAPTER" at the top left corner fol...
#
# --- figure-108-307.jpg ---
#  The image provided is highly pixelated and lacks clarity, making it difficult to discern any specif...
#
# --- figure-108-287.jpg ---
#  The image is a close-up photograph of a graphic or symbol that resembles an eye, colored purple and...
#
# --- figure-132-363.jpg ---
#  The image appears to be a screenshot of a slide from a presentation, featuring a chart and some tex...
#
# --- figure-64-71.jpg ---
#  The image shows a line graph with a night sky background and text overlaying it. The graph depicts ...
#
# --- figure-108-151.jpg ---
#  The image you've provided appears to be a low-resolution thumbnail of an image or video. It feature...
#
# --- figure-153-397.jpg ---
#  The image shows a digital book cover with a white background. At the top of the cover is the text "...
#
# --- figure-108-327.jpg ---
#  The image appears to be a screenshot of a computer screen displaying a graphical user interface for...
#
# --- figure-224-502.jpg ---
#  The image appears to be a digital graphic or an advertisement related to dental health, specificall...
#
# --- figure-108-160.jpg ---
#  The image provided is a close-up of two materials or substances with different colors and textures,...
#
# --- figure-83-88.jpg ---
#  The image shows a medical product next to its packaging. On the left side of the image is a pill bo...
#
# --- figure-231-513.jpg ---
#  The image appears to be a slide from a presentation, which includes a title and some textual inform...
#
# --- figure-273-542.jpg ---
#  The image is a graphical representation of an academic or scientific paper discussing genetic predi...
#
# --- figure-108-242.jpg ---
#  The image is a digital artwork that appears to be a promotional graphic with a game-like theme. It ...
#
# --- figure-108-180.jpg ---
#  The image you've provided appears to be a computer-generated graphic with a pixelated style that gi...
#
# --- figure-108-117.jpg ---
#  The image provided is of a drink with a pink hue that appears to be inside a glass. The color could...
#
# --- figure-108-144.jpg ---
#  The image provided appears to be a screenshot from a video or digital media content rather than a d...
#
# --- figure-84-91.jpg ---
#  The image shows a smartphone with its case partially removed, revealing a small sensor device attac...
#
# --- figure-124-351.jpg ---
#  The image is a bar graph with three bars and two lines representing different types of diabetes tre...
#
# --- figure-291-554.jpg ---
#  The image displays a puzzle with a gray background and blue interlocking pieces. Each piece has var...
#
# --- figure-212-478.jpg ---
#  The image is a flowchart that depicts the structure and functions of the human body with a focus on...
#
# --- figure-143-380.jpg ---
#  The image appears to be a screenshot from a presentation slide showing an ophthalmologic scan, like...
#
# --- figure-108-201.jpg ---
#  The image appears to be a screenshot from a webpage or a mobile device with a blurred or low-resolu...
#
# --- figure-108-124.jpg ---
#  The image is a close-up photograph featuring what appears to be a pattern of red and orange shapes ...
#
# --- figure-71-80.jpg ---
#  The image shows a person's back, focusing on an area with visible skin conditions that could be ind...
#
# --- figure-236-524.jpg ---
#  The image shows a human hand with five fingers extended upward. There is a distinct deformity of th...
#
# --- figure-172-426.jpg ---
#  The image is a bar graph with three bars representing different therapies: conventional therapy, in...
#
# --- figure-44-46.jpg ---
#  The image is a digital slide, likely from a presentation, featuring an educational diagram of a pro...
#
# --- figure-197-454.jpg ---
#  The image is a graphical representation with text overlay that appears to be related to pharmacolog...
#
# --- figure-17-6.jpg ---
#  The image shows a graphical representation of economic data for a specific year (2019), with three ...
#
# --- figure-97-104.jpg ---
#  The image shows a close-up of an individual's abdomen with a glucose monitoring device, commonly kn...
#
# --- figure-135-367.jpg ---
#  The image appears to be a slide from a presentation or educational material related to biochemistry...
#
# --- figure-247-529.jpg ---
#  The image shows a graphic design with a clear and simple composition. There are two main elements: ...
#
# --- figure-103-110.jpg ---
#  The image is a graph from a scientific study, specifically a clinical trial, as indicated by the la...
#
# --- figure-196-450.jpg ---
#  The image is a digital slide, likely from a presentation, with a graph and some additional elements...
#
# --- figure-108-157.jpg ---
#  The image provided is of low resolution and does not allow for clear details. It appears to be a sc...
#
# --- figure-108-249.jpg ---
#  The image is a close-up of a blurred object with a focus on a particular section, making it difficu...
#
# --- figure-108-166.jpg ---
#  The image is a close-up photograph of a person's face, focusing on the nose and part of the cheek. ...
#
# --- figure-224-510.jpg ---
#  The image appears to be a digital blend of two color swatches with different levels of opacity. On ...
#
# --- figure-43-45.jpg ---
#  The image appears to be a scientific or educational diagram that illustrates the complex interactio...
#
# --- figure-192-443.jpg ---
#  The image is a graphical representation of data related to survival from baseline, which seems to p...
#
# --- figure-31-20.jpg ---
#  The image appears to be a screenshot from a presentation slide or infographic. It features a map th...
#
# --- figure-118-346.jpg ---
#  The image is a screenshot of an electronic document or presentation slide with a focus on adult-ons...
#
# --- figure-108-302.jpg ---
#  The image you've shared is quite small and blurry, which makes it difficult to discern any specific...
#
# --- figure-108-338.jpg ---
#  The image appears to be a stylized, colorful graphic rather than a photograph of real items. It fea...
#
# --- figure-108-125.jpg ---
#  The image you've provided appears to be a composite of two different images. On the left side, ther...
#
# --- figure-19-9.jpg ---
#  The image is a black and white portrait of an individual sitting at a desk with his right hand rest...
#
# --- figure-108-133.jpg ---
#  The image is a vertical screenshot from an animated video. It features a close-up of an animated ch...
#
# --- figure-261-538.jpg ---
#  The image shows two infants lying on their backs next to each other within a hospital environment. ...
#
# --- figure-108-194.jpg ---
#  The image you've provided appears to be a screenshot of a graphical user interface (GUI) with a blu...
#
# --- figure-208-475.jpg ---
#  The image is a simple digital graphic with a clear focus on text. It features the number "22" promi...
#
# --- figure-108-335.jpg ---
#  The image you've provided is of low resolution and appears to be a screenshot from a webpage or an ...
#
# --- figure-108-128.jpg ---
#  The image is a composite of two separate visuals related to health education and anatomy lesson. Th...
#
# --- figure-1-2.jpg ---
#  The image is a close-up photograph of a person's hands holding a yellow device called a GlucoWatch,...
#
# --- figure-145-387.jpg ---
#  The image you've provided is an ultrasound scan of a fetus in utero. It appears to be a grayscale p...
#
# --- figure-108-231.jpg ---
#  The image you've provided appears to be a simple, low-resolution grayscale image that does not cont...
#
# --- figure-74-85.jpg ---
#  The image you've provided is a photograph of an individual lying on their back with a number of vis...
#
# --- figure-81-87.jpg ---
#  The image is a graphical representation of data. It shows a line chart with two axes. On the x-axis...
#
# --- figure-103-111.jpg ---
#  The image is a graph with two sets of data plotted against a common axis labeled "Percentage". Ther...
#
# --- figure-108-173.jpg ---
#  The image appears to be a digital illustration rather than an actual photograph. It features styliz...
#
# --- figure-158-402.jpg ---
#  The image you've provided appears to be a microscopic view of a tissue section with various cell ty...
#
# --- figure-108-332.jpg ---
#  The image shows a close-up of an object that appears to be made of wood and has a light brown color...
#
# --- figure-1-1.jpg ---
#  The image is a vertical collage of four photos, each depicting a different aspect related to health...
#
# --- figure-174-427.jpg ---
#  The image is a cover page of a book titled "Chapter 18" with a subtitle that reads "18". The cover ...
#
# --- figure-108-334.jpg ---
#  The image you've provided appears to be a digital graphic with an overlaid text and several icons t...
#
# --- figure-20-10.jpg ---
#  The image is a black and white photograph of an individual posing for the camera. The person appear...
#
# --- figure-108-135.jpg ---
#  The image shows a close-up of two objects with text overlaid. On the left side, there is a red obje...
#
# --- figure-192-441.jpg ---
#  The image is a line graph with two lines representing two different data sets. One line represents ...
#
# --- figure-108-263.jpg ---
#  The image shows a stylized ice cube with a blueish hue and two irregular sides, resembling an abstr...
#
# --- figure-251-531.jpg ---
#  The image is a composite of two different panels side by side. On the left, there's an image with a...
#
# --- figure-90-95.jpg ---
#  The image is a digital graphic that resembles an ebook cover. It displays a plain white background ...
#
# --- figure-221-487.jpg ---
#  The image is an educational diagram that illustrates the relationship between diet and metabolism i...
#
# --- figure-146-390.jpg ---
#  The image is a digital photograph of an ophthalmological examination being performed using a retina...
#
# --- figure-197-456.jpg ---
#  The image appears to be a screenshot from a presentation slide with a title that reads "Hazard Rati...
#
# --- figure-40-40.jpg ---
#  The image is a composite of two separate graphs related to diabetes research. On the left side, the...
#
# --- figure-161-408.jpg ---
#  The image shows a collage of three different figures related to health and lifestyle statistics. On...
#
# --- figure-108-179.jpg ---
#  The image appears to be a digital icon or logo with a predominantly orange and white color scheme. ...
#
# --- figure-108-319.jpg ---
#  The image appears to be a screenshot of an Instagram post featuring an animated character sitting a...
#
# --- figure-160-404.jpg ---
#  The image appears to be a scientific illustration or diagram, possibly from an academic paper or pr...
#
# --- figure-235-519.jpg ---
#  The image shows a close-up of a person's skin with a mole that appears to have a blistered or erode...
#
# --- figure-108-214.jpg ---
#  The image you've provided is not clear enough to discern any specific details such as texts, object...
#
# --- figure-204-470.jpg ---
#  The image shows a foot with several signs of infection or poor health. The toe on the left side is ...
#
# --- figure-234-515.jpg ---
#  The image depicts a close-up of a person's skin with several red, inflamed spots that resemble psor...
#
# --- figure-1-3.jpg ---
#  The image shows a pair of athletic shoes with blue laces resting on a bright teal surface, next to ...
#
# --- figure-217-483.jpg ---
#  The image displays a diagrammatic representation of an organ system, specifically focusing on the g...
#
# --- figure-108-283.jpg ---
#  The image provided appears to be a photograph with low resolution and quality, making it difficult ...
#
# --- figure-36-30.jpg ---
#  The image shows a close-up of a surface with a pattern that resembles cellular structures, possibly...
#
# --- figure-23-13.jpg ---
#  The image is a line graph with a x-axis labeled "Followup years" ranging from 6 to 10 years. There ...
#
# --- figure-108-155.jpg ---
#  The image depicts a cartoon character that resembles an ice cream sundae with various toppings and ...
#
# --- figure-108-227.jpg ---
#  The image provided is a close-up photograph of an object with a focus on a reflective surface, caus...
#
# --- figure-131-358.jpg ---
#  The image displays a flowchart with text and arrows to describe the metabolic pathways and changes ...
#
# --- figure-108-247.jpg ---
#  The image provided appears to be a close-up of an object with textured surfaces, possibly a materia...
#
# --- figure-146-391.jpg ---
#  The image displays a close-up view of a medical scan, specifically an OCT (Optical Coherence Tomogr...
#
# --- figure-96-103.jpg ---
#  The image displays a collection of diabetes-related items on a blue cloth surface. At the center is...
#
# --- figure-127-355.jpg ---
#  The image is a composite of two different images, both related to diabetes management, presented si...
#
# --- figure-108-313.jpg ---
#  The image provided is a grayscale vector graphic with a simple icon and an area of text. The icon a...
#
# --- figure-199-462.jpg ---
#  The image is a graphical representation of data related to men and women with prevalence rates and ...
#
# --- figure-187-439.jpg ---
#  The image is a photograph of a step-by-step guide with the title "Step 2 ACEi OR ARB IN AFRICAN COU...
#
# --- figure-125-352.jpg ---
#  The image is a slide from a presentation, featuring two panels that appear to explain the effects o...
#
# --- figure-176-432.jpg ---
#  The image depicts a diagram explaining the process of production of cholesterol in the circulation ...
#
# --- figure-108-119.jpg ---
#  The image is a composite that includes a medical illustration on the left side and a photographic r...
#
# --- figure-205-472.jpg ---
#  The image shows a pair of human feet, which appear to be bare and resting on a surface that could b...
#
# --- figure-192-444.jpg ---
#  The image presents a comparative view of histological staining of tissues with two distinct methods...
#
# --- figure-132-362.jpg ---
#  The image appears to be a graph from a scientific paper or presentation related to diabetes. It is ...
#
# --- figure-178-433.jpg ---
#  The image appears to be a diagrammatic representation of a scientific or educational material relat...

# %%
import uuid
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.storage import InMemoryStore
from langchain_chroma import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_core.documents import Document

# Initialize the HuggingFaceEmbeddings with the model you want
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# The vectorstore to use to index the child chunks
vectorstore = Chroma(
    collection_name="summaries", 
    embedding_function=embeddings
)

# The storage layer for the parent documents
store = InMemoryStore()
id_key = "doc_id"

# The retriever (empty to start)
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    docstore=store,
    id_key=id_key,
)
# Out:
# <ipython-input-15-1660da5509c1>:9: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Add texts
doc_ids = [str(uuid.uuid4()) for _ in texts]
summary_texts = [
    Document(page_content=s, metadata={id_key: doc_ids[i]})
    for i, s in enumerate(text_summaries)
]
retriever.vectorstore.add_documents(summary_texts)
retriever.docstore.mset(list(zip(doc_ids, texts)))

# Add tables
#table_ids = [str(uuid.uuid4()) for _ in tables]
#summary_tables = [
    #Document(page_content=s, metadata={id_key: table_ids[i]})
    #for i, s in enumerate(table_summaries)
#]
#retriever.vectorstore.add_documents(summary_tables)
#retriever.docstore.mset(list(zip(table_ids, tables)))

# Add images
img_ids = [str(uuid.uuid4()) for _ in image_descriptions]
summary_img = [
    Document(page_content=s, metadata={id_key: img_ids[i]})
    for i, s in enumerate(image_descriptions)
]
retriever.vectorstore.add_documents(summary_img)
retriever.docstore.mset(
    list(zip(img_ids, image_descriptions))
)

# %%
from langchain_core.runnables import RunnablePassthrough

# Prompt template
template = """Answer the question based only on the following context, which can include text and tables:
{context}
Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

# Option 1: LLM
model = Ollama(model="llama2")

# RAG pipeline
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
chain.invoke(
    "How do the World Health Organization (WHO) and the American Diabetes Association (ADA) define diabetes based on fasting plasma glucose (FPG) levels?"
)
# Out:
# "The World Health Organization (WHO) and the American Diabetes Association (ADA) define diabetes based on fasting plasma glucose (FPG) levels as follows:\n\n* For adults, a FPG level ≥126 mg/dL (7.0 mmol/L) is considered diagnostic of diabetes.\n* For children and adolescents, a FPG level ≥100 mg/dL (5.6 mmol/L) is considered diagnostic of diabetes.\n\nIt's worth noting that these criteria are based on the WHO and ADA's consensus guidelines, but other organizations may have slightly different criteria. Additionally, these criteria do not necessarily detect diabetes in the same individuals, as there can be variability in plasma glucose levels over time and between different ethnic groups."
